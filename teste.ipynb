# %% [markdown]
# <a href="https://colab.research.google.com/github/matheusjk/analiseDados/blob/main/teste.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install pandas

# %%
import pandas as pd

# print(pd.__version__)
# pd? # pega infos do o que é o pandas

pd.Series(['a','b','c', 'd'], index=[1,2,3,4], name='teste')

# df = pd.DataFrame(
#     {
#         "Nome": [
#             "João da Silva",
#             "Pedro Fernandes",
#             "Maria Paula",
#             "Fernanda da Cruz"
#         ],
#         "Idade": [22, 15, 3, 14],
#         "Sexo": ["Masculino", "Masculino", "Feminino", "Feminino"]
#     }
# )

# df["Idade"].min()
# Out:
# 1    a
# 2    b
# 3    c
# 4    d
# Name: teste, dtype: object

# %%
s1 = pd.Series(['a','b','c', 'd'], index=[1,2,3,4], name='teste')
s2 = pd.Series(['a','b','c', 'd'], index=[1,2,3,4], name='teste2')


pd.DataFrame(
    [s1, s2]
)

# Series basicamente um vetor ou matriz unidimensional 
# DataFrame é basicamente uma matriz bidimensional com colunas de tipos potencialmente diferentes. 

# https://github.com/programacaodinamica/dicas-pandas/blob/master/Pandas_do_ZERO_%C3%A0_An%C3%A1lise_de_Dados.ipynb
# Out:
#         1  2  3  4
# teste   a  b  c  d
# teste2  a  b  c  d

# %%
pd.read_csv?

# %%
covid = pd.read_csv("/content/drive/MyDrive/data/caso_full.csv")

# %%
municipios = pd.read_csv("/content/drive/MyDrive/data/municipios.csv")

# %%
# covid.to_csv('covid.csv')  para exportar os dados em csv

# %%
covid.head()  # mostra a cabeça do DataFrame mostra as 5 primeiras linhas do dado
# Out:
#          city  city_ibge_code        date  epidemiological_week  \
# 0  Rio Branco       1200401.0  2020-03-17                202012
# 1         NaN            12.0  2020-03-17                202012
# 2  Rio Branco       1200401.0  2020-03-18                202012
# 3         NaN            12.0  2020-03-18                202012
# 4  Rio Branco       1200401.0  2020-03-19                202012
#
#    estimated_population  estimated_population_2019  is_last  is_repeated  \
# 0              413418.0                   407319.0    False        False
# 1              894470.0                   881935.0    False        False
# 2              413418.0                   407319.0    False        False
# 3              894470.0                   881935.0    False        False
# 4              413418.0                   407319.0    False        False
#
#    last_available_confirmed  last_available_confirmed_per_100k_inhabitants  \
# ...

# %%
covid[covid.city.isnull() == False]  # pega os municipios que não tiverem nulo no campo   # covid.dropna(axis=1)
# Out:
#                  city  city_ibge_code        date  epidemiological_week  \
# 0          Rio Branco       1200401.0  2020-03-17                202012
# 2          Rio Branco       1200401.0  2020-03-18                202012
# 4          Rio Branco       1200401.0  2020-03-19                202012
# 6          Rio Branco       1200401.0  2020-03-20                202012
# 8          Rio Branco       1200401.0  2020-03-21                202012
# ...               ...             ...         ...                   ...
# 3853642    Tocantínia       1721109.0  2022-03-27                202213
# 3853643      Tupirama       1721257.0  2022-03-27                202213
# 3853644    Tupiratins       1721307.0  2022-03-27                202213
# 3853645  Wanderlândia       1722081.0  2022-03-27                202213
# 3853646       Xambioá       1722107.0  2022-03-27                202213
#
#          estimated_population  estimated_population_2019  is_last  \
# ...

# %%
municipios.head()
# Out:
#    codigo_ibge                 nome  latitude  longitude  capital  codigo_uf
# 0      5200050      Abadia de Goiás -16.75730   -49.4412        0         52
# 1      3100104  Abadia dos Dourados -18.48310   -47.3916        0         31
# 2      5200100            Abadiânia -16.19700   -48.7057        0         52
# 3      3100203               Abaeté -19.15510   -45.4444        0         31
# 4      1500107           Abaetetuba  -1.72183   -48.8788        0         15

# %%
covid.tail()  # mostra os ultimos registros do dado | tail == calda
# Out:
#                  city  city_ibge_code        date  epidemiological_week  \
# 3853643      Tupirama       1721257.0  2022-03-27                202213
# 3853644    Tupiratins       1721307.0  2022-03-27                202213
# 3853645  Wanderlândia       1722081.0  2022-03-27                202213
# 3853646       Xambioá       1722107.0  2022-03-27                202213
# 3853647           NaN            17.0  2022-03-27                202213
#
#          estimated_population  estimated_population_2019  is_last  \
# 3853643                1922.0                     1891.0    False
# 3853644                2729.0                     2671.0    False
# 3853645               11734.0                    11683.0    False
# 3853646               11520.0                    11540.0    False
# 3853647             1590248.0                  1572866.0    False
#
#          is_repeated  last_available_confirmed  \
# 3853643         True                       223
# ...

# %%
covid.index  # nos da a descrição do indice dos dados
# Out:
# RangeIndex(start=0, stop=3853648, step=1)

# %%
# covid.columns   # nos retorna todos os nomes das colunas do dado

# %%
covid.columns.values  # nos retorna em formato de array
# Out:
# array(['city', 'city_ibge_code', 'date', 'epidemiological_week',
#        'estimated_population', 'estimated_population_2019', 'is_last',
#        'is_repeated', 'last_available_confirmed',
#        'last_available_confirmed_per_100k_inhabitants',
#        'last_available_date', 'last_available_death_rate',
#        'last_available_deaths', 'order_for_place', 'place_type', 'state',
#        'new_confirmed', 'new_deaths'], dtype=object)

# %%
covid.describe()   # analise descritiva dos dados - estatistica
# Out:
#        city_ibge_code  epidemiological_week  estimated_population  \
# count    3.840002e+06          3.853648e+06          3.840002e+06
# mean     3.228321e+06          2.021052e+05          8.116488e+04
# std      1.009499e+06          5.755437e+01          9.057809e+05
# min      1.100000e+01          2.020090e+05          7.760000e+02
# 25%      2.509107e+06          2.020440e+05          5.602000e+03
# 50%      3.144508e+06          2.021160e+05          1.219500e+04
# 75%      4.117297e+06          2.021400e+05          2.689900e+04
# max      5.300108e+06          2.022130e+05          4.628933e+07
#
#        estimated_population_2019  last_available_confirmed  \
# count               3.840002e+06              3.853648e+06
# mean                8.054619e+04              4.777532e+03
# std                 8.992380e+05              6.180363e+04
# min                 7.810000e+02              0.000000e+00
# 25%                 5.603000e+03              1.420000e+02
# ...

# %%
covid.T  # transpoem os dados | pivot pega as linhas e transforma em colunas e colunas em linhas
# Out:
#                                                   0           1        \
# city                                           Rio Branco         NaN
# city_ibge_code                                  1200401.0        12.0
# date                                           2020-03-17  2020-03-17
# epidemiological_week                               202012      202012
# estimated_population                             413418.0    894470.0
# estimated_population_2019                        407319.0    881935.0
# is_last                                             False       False
# is_repeated                                         False       False
# last_available_confirmed                                3           3
# last_available_confirmed_per_100k_inhabitants     0.72566     0.33539
# last_available_date                            2020-03-17  2020-03-17
# last_available_death_rate                             0.0         0.0
# ...

# %%
covid[2:10]   # selecionando o dados via indice
# Out:
#          city  city_ibge_code        date  epidemiological_week  \
# 2  Rio Branco       1200401.0  2020-03-18                202012
# 3         NaN            12.0  2020-03-18                202012
# 4  Rio Branco       1200401.0  2020-03-19                202012
# 5         NaN            12.0  2020-03-19                202012
# 6  Rio Branco       1200401.0  2020-03-20                202012
# 7         NaN            12.0  2020-03-20                202012
# 8  Rio Branco       1200401.0  2020-03-21                202012
# 9         NaN            12.0  2020-03-21                202012
#
#    estimated_population  estimated_population_2019  is_last  is_repeated  \
# 2              413418.0                   407319.0    False        False
# 3              894470.0                   881935.0    False        False
# 4              413418.0                   407319.0    False        False
# 5              894470.0                   881935.0    False        False
# ...

# %%
covid['city']  # selecionando o dado por nome de coluna
# Out:
# 0            Rio Branco
# 1                   NaN
# 2            Rio Branco
# 3                   NaN
# 4            Rio Branco
#                ...
# 3853643        Tupirama
# 3853644      Tupiratins
# 3853645    Wanderlândia
# 3853646         Xambioá
# 3853647             NaN
# Name: city, Length: 3853648, dtype: object

# %%
covid[['city', 'estimated_population_2019']]  # selecionando o dado por nomes de colunas
# Out:
#                  city  estimated_population_2019
# 0          Rio Branco                   407319.0
# 1                 NaN                   881935.0
# 2          Rio Branco                   407319.0
# 3                 NaN                   881935.0
# 4          Rio Branco                   407319.0
# ...               ...                        ...
# 3853643      Tupirama                     1891.0
# 3853644    Tupiratins                     2671.0
# 3853645  Wanderlândia                    11683.0
# 3853646       Xambioá                    11540.0
# 3853647           NaN                  1572866.0
#
# [3853648 rows x 2 columns]

# %%
covid.loc[:, ["city","date"]]  # selecionando os dados via expressão | metodos  [:, ["coluna"]] [linha | [colunas1, coluna2, ...] ]
# Out:
#                  city        date
# 0          Rio Branco  2020-03-17
# 1                 NaN  2020-03-17
# 2          Rio Branco  2020-03-18
# 3                 NaN  2020-03-18
# 4          Rio Branco  2020-03-19
# ...               ...         ...
# 3853643      Tupirama  2022-03-27
# 3853644    Tupiratins  2022-03-27
# 3853645  Wanderlândia  2022-03-27
# 3853646       Xambioá  2022-03-27
# 3853647           NaN  2022-03-27
#
# [3853648 rows x 2 columns]

# %%
covid.loc[1000:2500, ["city","date"]]  # selecionando os dados via expressão | metodos  [:, ["coluna"]] [linha | [colunas1, coluna2, ...] ]
# Out:
#                       city        date
# 1000                 Feijó  2020-06-07
# 1001                Jordão  2020-06-07
# 1002         Manoel Urbano  2020-06-07
# 1003  Marechal Thaumaturgo  2020-06-07
# 1004           Mâncio Lima  2020-06-07
# ...                    ...         ...
# 2496                Jordão  2020-08-11
# 2497         Manoel Urbano  2020-08-11
# 2498  Marechal Thaumaturgo  2020-08-11
# 2499           Mâncio Lima  2020-08-11
# 2500     Plácido de Castro  2020-08-11
#
# [1501 rows x 2 columns]

# %%
covid.iloc[50]  # selecionando os dados como se fossem series no caso passando qual a linha | pra selecionar linha
# Out:
# city                                             Rio Branco
# city_ibge_code                                    1200401.0
# date                                             2020-04-04
# epidemiological_week                                 202014
# estimated_population                               413418.0
# estimated_population_2019                          407319.0
# is_last                                               False
# is_repeated                                           False
# last_available_confirmed                                 36
# last_available_confirmed_per_100k_inhabitants       8.70789
# last_available_date                              2020-04-04
# last_available_death_rate                               0.0
# last_available_deaths                                     0
# order_for_place                                          19
# place_type                                             city
# state                                                    AC
# ...

# %%
 # selecionando os dados passando as colunas via indice | não busca até o ultimo valor de coluna e sempre começa em zero

covid.iloc[:, 2:8]
# Out:
#                date  epidemiological_week  estimated_population  \
# 0        2020-03-17                202012              413418.0
# 1        2020-03-17                202012              894470.0
# 2        2020-03-18                202012              413418.0
# 3        2020-03-18                202012              894470.0
# 4        2020-03-19                202012              413418.0
# ...             ...                   ...                   ...
# 3853643  2022-03-27                202213                1922.0
# 3853644  2022-03-27                202213                2729.0
# 3853645  2022-03-27                202213               11734.0
# 3853646  2022-03-27                202213               11520.0
# 3853647  2022-03-27                202213             1590248.0
#
#          estimated_population_2019  is_last  is_repeated
# 0                         407319.0    False        False
# 1                         881935.0    False        False
# ...

# %%
covid[(covid['state'] == "RJ")]  ## Indexação Booleana
# Out:
#                    city  city_ibge_code        date  epidemiological_week  \
# 2481771     Barra Mansa       3300407.0  2020-03-05                202010
# 2481772             NaN            33.0  2020-03-05                202010
# 2481773     Barra Mansa       3300407.0  2020-03-06                202010
# 2481774  Rio de Janeiro       3304557.0  2020-03-06                202010
# 2481775             NaN            33.0  2020-03-06                202010
# ...                 ...             ...         ...                   ...
# 2549218         Valença       3306107.0  2022-03-27                202213
# 2549219       Varre-Sai       3306156.0  2022-03-27                202213
# 2549220       Vassouras       3306206.0  2022-03-27                202213
# 2549221   Volta Redonda       3306305.0  2022-03-27                202213
# 2549222             NaN            33.0  2022-03-27                202213
#
#          estimated_population  estimated_population_2019  is_last  \
# ...

# %%
## Indexação Booleana
## expressão booleana para filtro dos dados
 
covid[(covid['state'] == "RJ") | (covid['state'] == "SP") & (covid['last_available_date'] == '2022-02-01')]
# Out:
#                    city  city_ibge_code        date  epidemiological_week  \
# 2481771     Barra Mansa       3300407.0  2020-03-05                202010
# 2481772             NaN            33.0  2020-03-05                202010
# 2481773     Barra Mansa       3300407.0  2020-03-06                202010
# 2481774  Rio de Janeiro       3304557.0  2020-03-06                202010
# 2481775             NaN            33.0  2020-03-06                202010
# ...                 ...             ...         ...                   ...
# 2549219       Varre-Sai       3306156.0  2022-03-27                202213
# 2549220       Vassouras       3306206.0  2022-03-27                202213
# 2549221   Volta Redonda       3306305.0  2022-03-27                202213
# 2549222             NaN            33.0  2022-03-27                202213
# 3722939             NaN            35.0  2022-02-01                202205
#
#          estimated_population  estimated_population_2019  is_last  \
# ...

# %%
 covid[covid['state'] == 'RJ'].shape[0]  # ver a quantidade de linhas  # covid[covid['state'] == 'RJ'].count()
# Out:
# 67452

# %%
covid.select_dtypes("float")  # selecionar o tipo de campo no DataFrame
# Out:
#          city_ibge_code  estimated_population  estimated_population_2019  \
# 0             1200401.0              413418.0                   407319.0
# 1                  12.0              894470.0                   881935.0
# 2             1200401.0              413418.0                   407319.0
# 3                  12.0              894470.0                   881935.0
# 4             1200401.0              413418.0                   407319.0
# ...                 ...                   ...                        ...
# 3853643       1721257.0                1922.0                     1891.0
# 3853644       1721307.0                2729.0                     2671.0
# 3853645       1722081.0               11734.0                    11683.0
# 3853646       1722107.0               11520.0                    11540.0
# 3853647            17.0             1590248.0                  1572866.0
#
#          last_available_confirmed_per_100k_inhabitants  \
# ...

# %% [markdown]
# # **Operações**
#
#
#
# *   mean
# *   apply
# *   value_counts

# %%
covid['state'].unique()
# Out:
# array(['AC', 'AL', 'AM', 'AP', 'BA', 'CE', 'DF', 'ES', 'GO', 'MA', 'MG',
#        'MS', 'MT', 'PA', 'PB', 'PE', 'PI', 'PR', 'RJ', 'RN', 'RO', 'RR',
#        'RS', 'SC', 'SE', 'SP', 'TO'], dtype=object)

# %%
covid['new_confirmed'].mean()  # media
# Out:
# 13.857163394269534

# %%
# valores que cada item possui | quantidade(de entrada) que temos pra cada um dos estados nesse .csv 
covid['state'].value_counts()
# Out:
# MG    574802
# SP    448923
# RS    335719
# BA    287758
# PR    272487
# SC    204645
# GO    167029
# PB    154071
# PI    152463
# MA    151588
# CE    131734
# PE    131561
# RN    116993
# PA    102768
# MT     96994
# TO     95770
# AL     72120
# RJ     67452
# ES     56954
# MS     54377
# SE     52923
# AM     44620
# RO     37388
# AC     16150
# RR     12064
# AP     12061
# DF      2234
# Name: state, dtype: int64

# %%
# valores que cada item possui | quantidade(de entrada) que temos pra cada um dos estados nesse .csv 
covid['state'].value_counts(normalize=True)   # valores em percentual
# Out:
# MG    0.149158
# SP    0.116493
# RS    0.087117
# BA    0.074672
# PR    0.070709
# SC    0.053104
# GO    0.043343
# PB    0.039981
# PI    0.039563
# MA    0.039336
# CE    0.034184
# PE    0.034139
# RN    0.030359
# PA    0.026668
# MT    0.025169
# TO    0.024852
# AL    0.018715
# RJ    0.017503
# ES    0.014779
# MS    0.014111
# SE    0.013733
# AM    0.011579
# RO    0.009702
# AC    0.004191
# RR    0.003131
# AP    0.003130
# DF    0.000580
# Name: state, dtype: float64

# %%
 # aplicar uma função no DataFrame ou numa coluna
covid[['estimated_population_2019', "new_deaths"]].apply(lambda x: x.max())
# Out:
# estimated_population_2019    45919049.0
# new_deaths                       1389.0
# dtype: float64

# %%
covid['city_ibge_code'].sort_values(ascending=True)   # ordenando series
# Out:
# 2688483    11.0
# 2679195    11.0
# 2679141    11.0
# 2679087    11.0
# 2679033    11.0
#            ...
# 3754873     NaN
# 3755520     NaN
# 3756167     NaN
# 3756814     NaN
# 3757461     NaN
# Name: city_ibge_code, Length: 3853648, dtype: float64

# %%
covid.sort_values(by='city_ibge_code', ascending=True)  # ordenando um DataFrame
# Out:
#                            city  city_ibge_code        date  \
# 2688483                     NaN            11.0  2021-06-20
# 2679195                     NaN            11.0  2020-12-30
# 2679141                     NaN            11.0  2020-12-29
# 2679087                     NaN            11.0  2020-12-28
# 2679033                     NaN            11.0  2020-12-27
# ...                         ...             ...         ...
# 3754873  Importados/Indefinidos             NaN  2022-03-23
# 3755520  Importados/Indefinidos             NaN  2022-03-24
# 3756167  Importados/Indefinidos             NaN  2022-03-25
# 3756814  Importados/Indefinidos             NaN  2022-03-26
# 3757461  Importados/Indefinidos             NaN  2022-03-27
#
#          epidemiological_week  estimated_population  \
# 2688483                202125             1796460.0
# 2679195                202053             1796460.0
# 2679141                202053             1796460.0
# ...

# %%
covid.sort_values(by=['city_ibge_code', 'new_deaths'], ascending=True)   # ordenando com mais de uma coluna
# Out:
#                            city  city_ibge_code        date  \
# 2701659                     NaN            11.0  2022-02-19
# 2690427                     NaN            11.0  2021-07-26
# 2693289                     NaN            11.0  2021-09-17
# 2694477                     NaN            11.0  2021-10-09
# 2699445                     NaN            11.0  2022-01-09
# ...                         ...             ...         ...
# 1024913  Importados/Indefinidos             NaN  2020-08-29
# 1163423  Importados/Indefinidos             NaN  2021-02-07
# 1048853  Importados/Indefinidos             NaN  2020-09-26
# 1031753  Importados/Indefinidos             NaN  2020-09-06
# 1144613  Importados/Indefinidos             NaN  2021-01-16
#
#          epidemiological_week  estimated_population  \
# 2701659                202207             1796460.0
# 2690427                202130             1796460.0
# 2693289                202137             1796460.0
# ...

# %% [markdown]
# ##Graficos

# %%
covid['state'].value_counts().plot()

# %%
covid['state'].value_counts().plot(kind='hist')

# %%
covid['state'].value_counts().plot.bar()   # (kind='bar')

# %%
covid['state'].value_counts().plot(kind='bar')

# %%
covid.groupby(['state']).mean()
# Out:
#        city_ibge_code  epidemiological_week  estimated_population  \
# state
# AC       1.145277e+06         202103.316285          8.088437e+04
# AL       2.676374e+06         202104.399307          6.871805e+04
# AM       1.280432e+06         202102.583819          1.390509e+05
# AP       1.502446e+06         202102.442418          1.047541e+05
# BA       2.909504e+06         202105.194806          7.612988e+04
# CE       2.293966e+06         202102.588610          1.028101e+05
# DF       2.650080e+06         202098.262310          3.055149e+06
# ES       3.160011e+06         202102.143765          1.069716e+05
# GO       5.187922e+06         202106.799508          6.262207e+04
# MA       2.096214e+06         202104.172375          6.787022e+04
# MG       3.132857e+06         202106.993114          5.410555e+04
# MS       4.936039e+06         202106.032054          7.525871e+04
# MT       5.066116e+06         202106.245428          5.289200e+04
# ...

# %% [markdown]
# ## Agrupamento (Group By)

# %%
covid.groupby(['state']).mean()   # ['last_available_confirmed_per_100k_inhabitants']
# Out:
#        city_ibge_code  epidemiological_week  estimated_population  \
# state
# AC       1.145277e+06         202103.316285          8.088437e+04
# AL       2.676374e+06         202104.399307          6.871805e+04
# AM       1.280432e+06         202102.583819          1.390509e+05
# AP       1.502446e+06         202102.442418          1.047541e+05
# BA       2.909504e+06         202105.194806          7.612988e+04
# CE       2.293966e+06         202102.588610          1.028101e+05
# DF       2.650080e+06         202098.262310          3.055149e+06
# ES       3.160011e+06         202102.143765          1.069716e+05
# GO       5.187922e+06         202106.799508          6.262207e+04
# MA       2.096214e+06         202104.172375          6.787022e+04
# MG       3.132857e+06         202106.993114          5.410555e+04
# MS       4.936039e+06         202106.032054          7.525871e+04
# MT       5.066116e+06         202106.245428          5.289200e+04
# ...

# %% [markdown]
# # Agregação Merge | Join | Concat

# %%
 municipios[municipios['codigo_ibge'] == 3304557.0]   # municipios[municipios['codigo_ibge'] == covid['city_ibge_code']]
# Out:
#       codigo_ibge            nome  latitude  longitude  capital  codigo_uf
# 4207      3304557  Rio de Janeiro  -22.9129   -43.2003        1         33

# %%
covid[covid.city.isnull() == False]
# Out:
#                  city  city_ibge_code        date  epidemiological_week  \
# 0          Rio Branco       1200401.0  2020-03-17                202012
# 2          Rio Branco       1200401.0  2020-03-18                202012
# 4          Rio Branco       1200401.0  2020-03-19                202012
# 6          Rio Branco       1200401.0  2020-03-20                202012
# 8          Rio Branco       1200401.0  2020-03-21                202012
# ...               ...             ...         ...                   ...
# 3853642    Tocantínia       1721109.0  2022-03-27                202213
# 3853643      Tupirama       1721257.0  2022-03-27                202213
# 3853644    Tupiratins       1721307.0  2022-03-27                202213
# 3853645  Wanderlândia       1722081.0  2022-03-27                202213
# 3853646       Xambioá       1722107.0  2022-03-27                202213
#
#          estimated_population  estimated_population_2019  is_last  \
# ...

# %%
 municipios[municipios['codigo_ibge'] == 3304557.0]    #municipios[(municipios['nome'] == 'Rio de Janeiro')]
# Out:
#       codigo_ibge            nome  latitude  longitude  capital  codigo_uf
# 4207      3304557  Rio de Janeiro  -22.9129   -43.2003        1         33

# %%
municipios = pd.read_csv("/content/drive/MyDrive/data/municipios.csv")

# %%
municipios.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-0564780ab410> in <module>()
# ----> 1 municipios.head()
#
# NameError: name 'municipios' is not defined

# %%
municipios.
# Out:
# codigo_ibge     True
# nome            True
# latitude        True
# longitude       True
# capital        False
# codigo_uf       True
# dtype: bool
